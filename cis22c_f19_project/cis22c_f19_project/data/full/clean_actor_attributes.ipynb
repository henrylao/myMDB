# %%
import os
import pandas as pd
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '.~clean_actor_attributes.ipynb',
#  'clean_actor_attributes.ipynb',
#  'clean_movie_attributes.ipynb',
#  'name_basics_cleaned.tsv',
#  'name_basics_cleaned_no_index.tsv',
#  'name_basics_cleaned_with_index.tsv',
#  'name_basics_full.tsv',
#  'title_akas_full.tsv',
#  'title_basics_cleaned.tsv',
#  'title_basics_cleaned2.tsv',
#  'title_basics_full.tsv',
#  'title_episode_full.tsv',
#  'title_principals_full.tsv',
#  'title_ratings_full.tsv',
#  'Untitled.ipynb']

# %%
df = pd.read_csv("name_basics_full.tsv", sep = '\t')

# %%
df.head()
# Out:
#       nconst      primaryName birthYear deathYear  \
# 0  nm0000001     Fred Astaire      1899      1987
# 1  nm0000002    Lauren Bacall      1924      2014
# 2  nm0000003  Brigitte Bardot      1934        \N
# 3  nm0000004     John Belushi      1949      1982
# 4  nm0000005   Ingmar Bergman      1918      2007
#
#                 primaryProfession                           knownForTitles
# 0  soundtrack,actor,miscellaneous  tt0043044,tt0050419,tt0053137,tt0072308
# 1              actress,soundtrack  tt0117057,tt0038355,tt0037382,tt0071877
# 2     actress,soundtrack,producer  tt0054452,tt0059956,tt0049189,tt0057345
# 3         actor,writer,soundtrack  tt0072562,tt0080455,tt0078723,tt0077975
# 4           writer,director,actor  tt0050976,tt0083922,tt0069467,tt0050986

# %%
print(len(df))
# Out:
# 9732109

# %%
df.head(20)
# Out:
#        nconst          primaryName birthYear deathYear  \
# 0   nm0000001         Fred Astaire      1899      1987
# 1   nm0000002        Lauren Bacall      1924      2014
# 2   nm0000003      Brigitte Bardot      1934        \N
# 3   nm0000004         John Belushi      1949      1982
# 4   nm0000005       Ingmar Bergman      1918      2007
# 5   nm0000006       Ingrid Bergman      1915      1982
# 6   nm0000007      Humphrey Bogart      1899      1957
# 7   nm0000008        Marlon Brando      1924      2004
# 8   nm0000009       Richard Burton      1925      1984
# 9   nm0000010         James Cagney      1899      1986
# 10  nm0000011          Gary Cooper      1901      1961
# 11  nm0000012          Bette Davis      1908      1989
# 12  nm0000013            Doris Day      1922      2019
# 13  nm0000014  Olivia de Havilland      1916        \N
# 14  nm0000015           James Dean      1931      1955
# 15  nm0000016      Georges Delerue      1925      1992
# ...

# %%
df = df.replace('\\N', "Unavailable")

# %%
df.head(20)
# Out:
#        nconst          primaryName birthYear    deathYear  \
# 0   nm0000001         Fred Astaire      1899         1987
# 1   nm0000002        Lauren Bacall      1924         2014
# 2   nm0000003      Brigitte Bardot      1934  Unavailable
# 3   nm0000004         John Belushi      1949         1982
# 4   nm0000005       Ingmar Bergman      1918         2007
# 5   nm0000006       Ingrid Bergman      1915         1982
# 6   nm0000007      Humphrey Bogart      1899         1957
# 7   nm0000008        Marlon Brando      1924         2004
# 8   nm0000009       Richard Burton      1925         1984
# 9   nm0000010         James Cagney      1899         1986
# 10  nm0000011          Gary Cooper      1901         1961
# 11  nm0000012          Bette Davis      1908         1989
# 12  nm0000013            Doris Day      1922         2019
# 13  nm0000014  Olivia de Havilland      1916  Unavailable
# 14  nm0000015           James Dean      1931         1955
# ...

# %%
indexToDrop = df[ df['birthYear'] == "Unavailable"].index
df.drop(indexToDrop, inplace = True)

# %%
len(df)
# Out:
# 492086

# %%
df.tail()
# Out:
#             nconst         primaryName birthYear deathYear primaryProfession  \
# 9731832  nm9993426  Nick 'Duffy' Fudge      1989      2018               NaN
# 9731837  nm9993432        Albert Minns      1920      1985               NaN
# 9731838  nm9993434   Richard Blackmarr      1929      2013               NaN
# 9731839  nm9993435        William Riva      1919      1999     set_decorator
# 9731840  nm9993436      Frank J. Gaily      1915      2008  sound_department
#
#         knownForTitles
# 9731832    Unavailable
# 9731837      tt0189339
# 9731838      tt0189339
# 9731839      tt0189339
# 9731840      tt0189339

# %%
df.to_csv("name_basics_cleaned_with_index_and_label.tsv", sep = '\t', index = False)

# %%
df.to_csv("name_basics_cleaned_no_index.tsv", sep = '|', index = False)

# %%
df.tail()
# Out:
#             nconst         primaryName birthYear deathYear primaryProfession  \
# 9731832  nm9993426  Nick 'Duffy' Fudge      1989      2018               NaN
# 9731837  nm9993432        Albert Minns      1920      1985               NaN
# 9731838  nm9993434   Richard Blackmarr      1929      2013               NaN
# 9731839  nm9993435        William Riva      1919      1999     set_decorator
# 9731840  nm9993436      Frank J. Gaily      1915      2008  sound_department
#
#         knownForTitles
# 9731832    Unavailable
# 9731837      tt0189339
# 9731838      tt0189339
# 9731839      tt0189339
# 9731840      tt0189339

# %%
# Out:
#             nconst         primaryName birthYear    deathYear  \
# 0        nm0000001        Fred Astaire      1899         1987
# 1        nm0000002       Lauren Bacall      1924         2014
# 2        nm0000003     Brigitte Bardot      1934  Unavailable
# 3        nm0000004        John Belushi      1949         1982
# 4        nm0000005      Ingmar Bergman      1918         2007
# ...            ...                 ...       ...          ...
# 9731832  nm9993426  Nick 'Duffy' Fudge      1989         2018
# 9731837  nm9993432        Albert Minns      1920         1985
# 9731838  nm9993434   Richard Blackmarr      1929         2013
# 9731839  nm9993435        William Riva      1919         1999
# 9731840  nm9993436      Frank J. Gaily      1915         2008
#
#                       primaryProfession  \
# 0        soundtrack,actor,miscellaneous
# 1                    actress,soundtrack
# 2           actress,soundtrack,producer
# 3               actor,writer,soundtrack
# ...
